# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaYCG99/Introciencia-de-Datos/blob/main/BasedeDatos_Anime2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = ("/content/drive/MyDrive/Intro_Ciencia_de_Datos/Anime_rank.csv")
df = pd.read_csv(url)
df
# Out:
#        UID                                           Title  Rank Stream type  \
# 0        1                               Sousou no Frieren     1         TV
# 1        2                Fullmetal Alchemist: Brotherhood     2         TV
# 2        3                                     Steins;Gate     3         TV
# 3        4                                        Gintama°     4         TV
# 4        5              Shingeki no Kyojin Season 3 Part 2     5         TV
# ...    ...                                             ...   ...         ...
# 8645  8646                           Hypersonic Music Club  8646        ONA
# 8646  8647                    Iron Man: Rise of Technovore  8647        OVA
# 8647  8648           Jewelpet Movie: Sweets Dance Princess  8648      Movie
# 8648  8649                                  Si Hai Jing Qi  8649        ONA
# 8649  8650  Sore Ike! Anpanman: Black Nose to Mahou no Uta  8650      Movie
#
# ...

# %%
df.shape
# Out:
# (8650, 9)

# %%
df.columns
# Out:
# Index(['UID', 'Title', 'Rank', 'Stream type', 'Episodes', 'Start date',
#        'End date', 'Members', 'Score'],
#       dtype='object')

# %%
df['Title'].unique()
# Out:
# array(['Sousou no Frieren', 'Fullmetal Alchemist: Brotherhood',
#        'Steins;Gate', ..., 'Jewelpet Movie: Sweets Dance Princess',
#        'Si Hai Jing Qi', 'Sore Ike! Anpanman: Black Nose to Mahou no Uta'],
#       dtype=object)

# %%
df['Title'].nunique()
# Out:
# 8646

# %%
df['Rank'].nunique()
# Out:
# 8650

# %%
df['Stream type'].nunique()
# Out:
# 6

# %%
df['Stream type'].unique()
# Out:
# array(['TV ', 'Movie ', 'OVA ', 'ONA ', 'TV Special ', 'Special '],
#       dtype=object)

# %%
df['Episodes'].nunique()
# Out:
# 173

# %%
df['Episodes'].unique()
# Out:
# array([2.800e+01, 6.400e+01, 2.400e+01, 5.100e+01, 1.000e+01, 1.000e+00,
#        1.480e+02, 1.100e+02, 1.300e+01, 1.200e+01,       nan, 2.010e+02,
#        2.200e+01, 2.500e+01, 2.000e+00, 1.400e+01, 7.400e+01, 7.000e+00,
#        2.300e+01, 2.600e+01, 1.600e+01, 7.500e+01, 1.100e+01, 4.700e+01,
#        4.000e+00, 4.300e+01, 2.700e+01, 3.700e+01, 3.900e+01, 1.010e+02,
#        9.900e+01, 8.000e+00, 1.120e+02, 1.500e+01, 6.000e+00, 6.200e+01,
#        1.200e+02, 1.040e+02, 5.000e+01, 3.300e+01, 2.000e+01, 1.700e+01,
#        4.000e+01, 2.370e+02, 7.900e+01, 9.400e+01, 3.000e+00, 5.200e+01,
#        5.000e+02, 7.800e+01, 1.300e+02, 7.700e+01, 9.600e+01, 3.000e+01,
#        2.910e+02, 7.000e+01, 5.400e+01, 1.700e+02, 3.800e+01, 2.030e+02,
#        6.300e+01, 1.020e+02, 2.100e+01, 5.000e+00, 1.030e+02, 4.500e+01,
#        2.200e+02, 1.530e+02, 1.090e+02, 3.400e+01, 3.660e+02, 9.000e+00,
#        1.450e+02, 6.900e+01, 3.600e+01, 1.670e+02, 7.600e+01, 6.000e+01,
# ...

# %%
df['Start date'].nunique()
# Out:
# 650

# %%
df['End date'].nunique()
# Out:
# 641

# %%
df['Members'].nunique()
# Out:
# 8032

# %%
df['Score'].nunique()
# Out:
# 287

# %%
df.dtypes
# Out:
# UID              int64
# Title           object
# Rank             int64
# Stream type     object
# Episodes       float64
# Start date      object
# End date        object
# Members         object
# Score          float64
# dtype: object

# %%
df.describe()
# Out:
#                UID         Rank     Episodes        Score
# count  8650.000000  8650.000000  8608.000000  8650.000000
# mean   4325.500000  4325.500000    15.245818     7.039057
# std    2497.184248  2497.184248    34.188955     0.593492
# min       1.000000     1.000000     1.000000     6.150000
# 25%    2163.250000  2163.250000     1.000000     6.550000
# 50%    4325.500000  4325.500000    11.000000     6.970000
# 75%    6487.750000  6487.750000    13.000000     7.420000
# max    8650.000000  8650.000000  1787.000000     9.350000

# %%
df.sort_values('Episodes', ascending=False)
# Out:
#        UID                       Title  Rank Stream type  Episodes Start date  \
# 919    920             Doraemon (1979)   920         TV     1787.0  Apr 1979
# 4402  4403           Ninja Hattori-kun  4403         TV      694.0  Sep 1981
# 7611  7612  Xi Yangyang Yu Hui Tailang  7612         TV      530.0  Aug 2005
# 5903  5904               Perman (1983)  5904         TV      526.0  Apr 1983
# 8446  8447     Obake no Q-tarou (1985)  8447         TV      510.0  Apr 1985
# ...    ...                         ...   ...         ...       ...        ...
# 7559  7560                   Ojarumaru  7560         TV        NaN  Oct 1998
# 7721  7722  Shadowverse Flame: Arc-hen  7722         TV        NaN  Apr 2024
# 7970  7971          Tom to Jerry (ONA)  7971        ONA        NaN  Nov 2022
# 8338  8339            Himitsu no AiPri  8339         TV        NaN  Apr 2024
# 8470  8471                 Grendizer U  8471         TV        NaN  Jul 2024
#
#        End date  Members  Score
# ...
