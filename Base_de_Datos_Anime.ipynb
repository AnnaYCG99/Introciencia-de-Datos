# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaYCG99/Introciencia-de-Datos/blob/main/Base_de_Datos_Anime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/jarsmp37/introds/main/Anime_rank.csv'
df=pd.read_csv(url)
df.head(5)
# Out:
#    UID                               Title  Rank Stream type  Episodes  \
# 0    1                   Sousou no Frieren     1         TV       28.0
# 1    2    Fullmetal Alchemist: Brotherhood     2         TV       64.0
# 2    3                         Steins;Gate     3         TV       24.0
# 3    4                            Gintama°     4         TV       51.0
# 4    5  Shingeki no Kyojin Season 3 Part 2     5         TV       10.0
#
#   Start date   End date     Members  Score
# 0  Sep 2023    Mar 2024    800,615    9.35
# 1  Apr 2009    Jul 2010  3,373,923    9.09
# 2  Apr 2011    Sep 2011  2,584,616    9.07
# 3  Apr 2015    Mar 2016    636,631    9.06
# 4  Apr 2019    Jul 2019  2,305,044    9.05

# %%
df.columns
# Out:
# Index(['UID', 'Title', 'Rank', 'Stream type', 'Episodes', 'Start date',
#        'End date', 'Members', 'Score'],
#       dtype='object')

# %%
df.shape
# Out:
# (8650, 9)

# %%
df['Title'].value_counts()
# Out:
# Title
# Boku ga Aishita Subete no Kimi e                  2
# Dragon Ball Kai (2014)                            2
# Kyougoku Natsuhiko: Kousetsu Hyaku Monogatari     2
# Shen Lan Qi Yu Wushuang Zhu: Tianmo Pian          2
# Sousou no Frieren                                 1
#                                                  ..
# Ahiru no Sora                                     1
# Sekirei: Pure Engagement                          1
# Sankarea                                          1
# Saber Marionette J to X                           1
# Sore Ike! Anpanman: Black Nose to Mahou no Uta    1
# Name: count, Length: 8646, dtype: int64

# %%
df['Episodes'].unique()
# Out:
# array([2.800e+01, 6.400e+01, 2.400e+01, 5.100e+01, 1.000e+01, 1.000e+00,
#        1.480e+02, 1.100e+02, 1.300e+01, 1.200e+01,       nan, 2.010e+02,
#        2.200e+01, 2.500e+01, 2.000e+00, 1.400e+01, 7.400e+01, 7.000e+00,
#        2.300e+01, 2.600e+01, 1.600e+01, 7.500e+01, 1.100e+01, 4.700e+01,
#        4.000e+00, 4.300e+01, 2.700e+01, 3.700e+01, 3.900e+01, 1.010e+02,
#        9.900e+01, 8.000e+00, 1.120e+02, 1.500e+01, 6.000e+00, 6.200e+01,
#        1.200e+02, 1.040e+02, 5.000e+01, 3.300e+01, 2.000e+01, 1.700e+01,
#        4.000e+01, 2.370e+02, 7.900e+01, 9.400e+01, 3.000e+00, 5.200e+01,
#        5.000e+02, 7.800e+01, 1.300e+02, 7.700e+01, 9.600e+01, 3.000e+01,
#        2.910e+02, 7.000e+01, 5.400e+01, 1.700e+02, 3.800e+01, 2.030e+02,
#        6.300e+01, 1.020e+02, 2.100e+01, 5.000e+00, 1.030e+02, 4.500e+01,
#        2.200e+02, 1.530e+02, 1.090e+02, 3.400e+01, 3.660e+02, 9.000e+00,
#        1.450e+02, 6.900e+01, 3.600e+01, 1.670e+02, 7.600e+01, 6.000e+01,
# ...

# %%
df['Episodes'].nunique()
# Out:
# 173

# %%
df.dtypes
# Out:
# UID              int64
# Title           object
# Rank             int64
# Stream type     object
# Episodes       float64
# Start date      object
# End date        object
# Members         object
# Score          float64
# dtype: object

# %%
df.describe()
# Out:
#                UID         Rank     Episodes        Score
# count  8650.000000  8650.000000  8608.000000  8650.000000
# mean   4325.500000  4325.500000    15.245818     7.039057
# std    2497.184248  2497.184248    34.188955     0.593492
# min       1.000000     1.000000     1.000000     6.150000
# 25%    2163.250000  2163.250000     1.000000     6.550000
# 50%    4325.500000  4325.500000    11.000000     6.970000
# 75%    6487.750000  6487.750000    13.000000     7.420000
# max    8650.000000  8650.000000  1787.000000     9.350000
